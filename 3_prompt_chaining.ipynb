# %%
from langgraph.graph import StateGraph, START , END
from langchain_ollama import OllamaLLM
from typing import TypedDict

# %%
model = OllamaLLM(model="llama3")

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state:BlogState)->BlogState:

    #fetch title
    title = state['title']

    #call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topiv - {title}'
    outline  = model.invoke(prompt)

    #update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState)->BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'
    content = model.invoke(prompt)

    state['content']=content

    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

#edges
graph.add_edge(START , 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
intial_state = {'title':'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance
# * Context: Why India is an attractive market for AI adoption
# * Thesis statement: The rise of AI in India is transforming various industries, and this blog will explore the key trends, applications, and opportunities in this space.
#
# **II. Current State of AI in India**
#
# * Overview of the current state of AI in India, including:
# 	+ Government initiatives and policies supporting AI development
# 	+ Key players and startups driving innovation
# 	+ Challenges and limitations faced by the Indian AI ecosystem
#
# **III. Applications of AI in India**
#
# * In-depth exploration of AI applications in various industries, such as:
# 	+ Healthcare: AI-powered diagnostic tools, patient engagement platforms, and personalized medicine
# 	+ Finance: AI-driven lending platforms, fraud detection systems, and investment analysis tools
# 	+ Retail: AI-based customer service chatbots, product recommendations, and supply chain optimization
# 	+ Education: AI-powered learning management systems, adaptive assessments, and virtual teaching assistants
#
# **IV. Trends Shaping the Future of AI in India**
#
# * Discussion of key trends influencing the growth of AI in India, including:
# 	+ Increasing adoption of cloud computing and data analytics platforms
# 	+ Growing demand for Explainable AI (XAI) solutions
# 	+ Rise of edge AI and IoT-based applications
# 	+ Increased focus on ethics, privacy, and transparency in AI development
#
# **V. Challenges and Opportunities**
#
# * Examination of the challenges facing the Indian AI ecosystem, such as:
# 	+ Limited availability of high-quality training data
# 	+ Skills gap among developers and researchers
# 	+ Concerns around job displacement and societal impact
# * Exploration of opportunities for growth and innovation, including:
# 	+ Government initiatives to promote AI adoption
# 	+ Partnerships between industry players and startups
# 	+ Growing demand for AI-powered services in emerging industries
#
# **VI. Case Studies**
#
# * In-depth analysis of successful AI applications or projects in India, such as:
# 	+ AI-powered chatbots improving customer service experiences
# 	+ Predictive analytics platforms optimizing supply chain operations
# 	+ AI-driven diagnostic tools improving healthcare outcomes
#
# **VII. Conclusion**
#
# * Recap of the key trends, applications, and opportunities in AI in India
# * Final thoughts on the potential for AI to transform industries and improve lives in India
# * Call-to-action: Encouragement for readers to explore AI applications and contribute to the growth of this exciting field.
#
# This outline should provide a comprehensive framework for exploring the rise of AI in India. Good luck with your blog!
