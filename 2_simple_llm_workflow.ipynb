# %%
from langgraph.graph import StateGraph, START , END
from langchain_ollama import OllamaLLM
from typing import TypedDict
from dotenv import load_dotenv

# %%
model = OllamaLLM(model="llama3")

# %%
#create state
class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt)

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
#create graph

graph = StateGraph(LLMState)

#add nodes
graph.add_node('llm_qa',llm_qa)

#add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

#compile
workflow = graph.compile()

# %%
intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The average distance from the Earth to the Moon is about 384,400 kilometers (238,900 miles). This is called the "lunar distance" or "average orbital distance." However, the Moon's orbit is not a perfect circle and its distance from Earth varies slightly due to the elliptical shape of its orbit.
#
# At its closest point, known as "perigee," the Moon is about 356,400 kilometers (221,500 miles) away from Earth. At its farthest point, or "apogee," it is around 405,500 kilometers (252,000 miles) away.
#
# It's worth noting that the Moon is slowly moving away from Earth at a rate of about 3.8 centimeters (1.5 inches) per year due to the tidal interactions between the two bodies.
